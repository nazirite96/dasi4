# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
car_df = pd.read_csv('./cars.csv')
brand_df = pd.read_csv('./brand.csv')

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history
# 0             NaN
# 1            Full
# 2             NaN
# 3            Full
# ...

# %%
brand_df.head()
# Out:
#       title         country
# 0     skoda  Czech Republic
# 1  vauxhall  United Kingdom
# 2   hyundai     South Korea
# 3      mini  United Kingdom
# 4      ford   United States

# %%
car_df['brand'] = car_df['title'].str.split(expand=True)[0]

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand
# 0             NaN     SKODA
# 1            Full  VAUXHALL
# ...

# %%
brand_df['title'] = brand_df['title'].str.upper()

# %%
brand_df.head(10)
# Out:
#            title         country
# 0          SKODA  Czech Republic
# 1       VAUXHALL  United Kingdom
# 2        HYUNDAI     South Korea
# 3           MINI  United Kingdom
# 4           FORD   United States
# 5          VOLVO          Sweden
# 6        PEUGEOT          France
# 7            BMW         Germany
# 8        CITROEN          France
# 9  MERCEDES-BENZ         Germany

# %%
car_df = car_df.merge(brand_df,how='left', left_on='brand', right_on='title')

# %%
car_df.head()
# Out:
#           title_x  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand   title_y         country
# ...

# %%
car_df = car_df.drop(['title_y'],axis=1)

# %%
car_df = car_df.rename({'title_x': 'title'}, axis=1)

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand         country
# 0             NaN     SKODA  Czech Republic
# ...

# %%
bonus_df = car_df.copy()

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3687 entries, 0 to 3686
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3687 non-null   object
#  1   Price              3687 non-null   int64
#  2   Mileage(miles)     3687 non-null   int64
#  3   Registration_Year  3687 non-null   int64
#  4   Previous Owners    2276 non-null   float64
#  5   Fuel type          3687 non-null   object
#  6   Body type          3687 non-null   object
#  7   Engine             3642 non-null   object
#  8   Gearbox            3687 non-null   object
#  9   Doors              3662 non-null   float64
#  10  Seats              3652 non-null   float64
#  11  Emission Class     3600 non-null   object
#  12  Service history    540 non-null    object
#  13  brand              3687 non-null   object
#  14  country            3687 non-null   object
# dtypes: float64(3), int64(3), object(9)
# ...

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type Engine Gearbox  Doors  Seats Emission Class  \
# 0    Diesel  Hatchback   1.4L  Manual    5.0    5.0         Euro 6
# 1    Petrol  Hatchback   1.2L  Manual    3.0    5.0         Euro 4
# 2    Petrol  Hatchback   1.4L  Manual    5.0    5.0         Euro 5
# 3    Petrol  Hatchback   1.4L  Manual    3.0    4.0         Euro 4
# 4    Diesel  Hatchback   1.3L  Manual    5.0    5.0         Euro 5
#
#   Service history     brand         country
# 0             NaN     SKODA  Czech Republic
# ...

# %%
car_df['Engine'] = car_df['Engine'].str[:-1]

# %%
car_df['Emission Class'] = car_df['Emission Class'].str[-1:]

# %%
car_df['Engine'] = pd.to_numeric(car_df['Engine'])

# %%
car_df['Emission Class'] = pd.to_numeric(car_df['Emission Class'])

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3687 entries, 0 to 3686
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              3687 non-null   object
#  1   Price              3687 non-null   int64
#  2   Mileage(miles)     3687 non-null   int64
#  3   Registration_Year  3687 non-null   int64
#  4   Previous Owners    2276 non-null   float64
#  5   Fuel type          3687 non-null   object
#  6   Body type          3687 non-null   object
#  7   Engine             3642 non-null   float64
#  8   Gearbox            3687 non-null   object
#  9   Doors              3662 non-null   float64
#  10  Seats              3652 non-null   float64
#  11  Emission Class     3600 non-null   float64
#  12  Service history    540 non-null    object
#  13  brand              3687 non-null   object
#  14  country            3687 non-null   object
# dtypes: float64(5), int64(3), object(7)
# ...

# %%
car_df.describe()
# Out:
#               Price  Mileage(miles)  Registration_Year  Previous Owners  \
# count   3687.000000    3.687000e+03        3687.000000      2276.000000
# mean    5787.301058    8.132854e+04        2011.846216         2.807557
# std     4480.629885    3.941718e+04           5.082387         1.546028
# min      400.000000    1.000000e+00        1953.000000         1.000000
# 25%     2490.000000    5.698400e+04        2008.000000         2.000000
# 50%     4000.000000    8.000000e+04        2012.000000         3.000000
# 75%     7995.000000    1.030000e+05        2015.500000         4.000000
# max    33900.000000    1.110100e+06        2025.000000         9.000000
#
#             Engine        Doors        Seats  Emission Class
# count  3642.000000  3662.000000  3652.000000     3600.000000
# mean      1.606260     4.321409     4.900329        4.910000
# std       0.486584     0.986760     0.577046        0.910688
# min       0.800000     2.000000     2.000000        1.000000
# ...

# %%
car_df.isna().mean()
# Out:
# title                0.000000
# Price                0.000000
# Mileage(miles)       0.000000
# Registration_Year    0.000000
# Previous Owners      0.382696
# Fuel type            0.000000
# Body type            0.000000
# Engine               0.012205
# Gearbox              0.000000
# Doors                0.006781
# Seats                0.009493
# Emission Class       0.023596
# Service history      0.853539
# brand                0.000000
# country              0.000000
# dtype: float64

# %%
car_df['Service history'].unique()
# Out:
# array([nan, 'Full'], dtype=object)

# %%
car_df.groupby('Service history')['Price'].mean()
# Out:
# Service history
# Full    7290.209259
# Name: Price, dtype: float64

# %%
car_df['Service history'] = car_df['Service history'].fillna('Uknown')

# %%
car_df.groupby('Service history')['Price'].mean()
# Out:
# Service history
# Full      7290.209259
# Uknown    5529.414045
# Name: Price, dtype: float64

# %%
car_df[car_df['Engine'].isna()]
# Out:
#                    title  Price  Mileage(miles)  Registration_Year  \
# 679         BMW 3 SERIES   4200           68060               2007
# 835        TOYOTA MARK X   7500           77000               2021
# 856         NISSAN CUBIC   4500           47000               2007
# 1087             AUDI A1   7995           50500               2012
# 1304        MAZDA MAZDA6   1500          155670               2015
# 1429          FORD FOCUS   1895          109000               2009
# 1533          CITROEN C1   3900           71000               2015
# 1619             FORD KA   2490           68837               2007
# 2022             AUDI A3   5750          139225               2012
# 2136        TOYOTA PRIUS   8950           66000               2012
# 2194         MAZDA MX-30  13899           13865               2021
# 2288         NISSAN LEAF   5390           60695               2014
# 2299         NISSAN LEAF   5390           60695               2014
# ...

# %%
car_df['na_values'] = car_df.isna().sum(axis = 1)

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              NaN
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              NaN
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history     brand         country  na_values
# ...

# %%
len(car_df[car_df['na_values'] >= 4])
# Out:
# 13

# %%
car_df = car_df[car_df['na_values'] < 4]

# %%
car_df.drop('na_values', axis = 1, inplace = True)
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
car_df.isna().mean()
# Out:
# title                0.000000
# Price                0.000000
# Mileage(miles)       0.000000
# Registration_Year    0.000000
# Previous Owners      0.382961
# Fuel type            0.000000
# Body type            0.000000
# Engine               0.009526
# Gearbox              0.000000
# Doors                0.003266
# Seats                0.005988
# Emission Class       0.020142
# Service history      0.000000
# brand                0.000000
# country              0.000000
# dtype: float64

# %%
sns.displot(car_df['Previous Owners'])

# %%
car_df['Previous Owners'].median()
# Out:
# 3.0

# %%
sns.displot(car_df['Engine'])

# %%
car_df['Engine'].mean()
# Out:
# 1.6061555372355043

# %%
car_df['Engine'].median()
# Out:
# 1.6

# %%
sns.displot(car_df['Doors'])

# %%
car_df['Doors'].median()
# Out:
# 5.0

# %%
sns.displot(car_df['Seats'])

# %%
sns.displot(car_df['Emission Class'])

# %%
# Previous Owners      0.382961
# Engine               0.009526
# Doors                0.003266
# Seats                0.005988
# Emission Class       0.020142
car_df['Previous Owners'] = car_df['Previous Owners'].fillna(car_df['Previous Owners'].median())
# Out:
# /tmp/ipykernel_55/347689619.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_df['Previous Owners'] = car_df['Previous Owners'].fillna(car_df['Previous Owners'].median())

# %%
car_df['Engine'] = car_df['Engine'].fillna(car_df['Engine'].median())
# Out:
# /tmp/ipykernel_55/2345776541.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_df['Engine'] = car_df['Engine'].fillna(car_df['Engine'].median())

# %%
car_df.loc[:,'Doors'] = car_df['Doors'].fillna(car_df['Doors'].median())
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
car_df.isna().mean()
# Out:
# title                0.0
# Price                0.0
# Mileage(miles)       0.0
# Registration_Year    0.0
# Previous Owners      0.0
# Fuel type            0.0
# Body type            0.0
# Engine               0.0
# Gearbox              0.0
# Doors                0.0
# Seats                0.0
# Emission Class       0.0
# Service history      0.0
# brand                0.0
# country              0.0
# dtype: float64

# %%
car_df['Seats'] = car_df['Seats'].fillna(car_df['Seats'].median()).copy()
# Out:
# /tmp/ipykernel_55/2629865535.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_df['Seats'] = car_df['Seats'].fillna(car_df['Seats'].median()).copy()

# %%
car_df.loc[:,'Emission Class'] = car_df['Emission Class'].fillna(car_df['Emission Class'].median()).copy()
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
car_df['Price'].sort_values()
# Out:
# 3245      400
# 3278      450
# 1238      495
# 3246      499
# 3429      500
#         ...
# 3102    25995
# 3230    25995
# 3224    28240
# 2936    30000
# 3212    33900
# Name: Price, Length: 3674, dtype: int64

# %%
car_df['Mileage(miles)'].sort_values()
# Out:
# 3219          1
# 3100          1
# 2013          6
# 3102        222
# 2760       1048
#          ...
# 1259     274100
# 1283     274100
# 2048     274100
# 1946     274100
# 1037    1110100
# Name: Mileage(miles), Length: 3674, dtype: int64

# %%
car_df[car_df['Mileage(miles)'] < 1000]
# Out:
#            title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 2013       MG ZT  15500               6               2004              4.0
# 3100    MG MG ZS  18365               1               2023              3.0
# 3102  SEAT ATECA  25995             222               2023              3.0
# 3219    MG MG ZS  18515               1               2023              3.0
#
#      Fuel type Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 2013    Petrol    Saloon     1.8  Manual    4.0    5.0             3.0
# 3100    Petrol       SUV     1.5  Manual    5.0    5.0             6.0
# 3102    Petrol       SUV     1.5  Manual    5.0    5.0             6.0
# 3219    Petrol       SUV     1.5  Manual    5.0    5.0             6.0
#
#      Service history brand         country
# 2013          Uknown    MG  United Kingdom
# 3100          Uknown    MG  United Kingdom
# 3102          Uknown  SEAT           Spain
# 3219          Uknown    MG  United Kingdom

# %%
car_df = car_df[car_df['Mileage(miles)'] > 1000]

# %%
car_df['Registration_Year'].sort_values()
# Out:
# 3024    1953
# 237     1972
# 2375    1981
# 1239    1985
# 1353    1987
#         ...
# 3140    2022
# 2760    2023
# 3173    2023
# 2967    2023
# 8       2025
# Name: Registration_Year, Length: 3670, dtype: int64

# %%
car_df = car_df[car_df['Registration_Year'] < 2025]

# %%
car_df['Previous Owners'].sort_values()
# Out:
# 1949    1.0
# 530     1.0
# 3134    1.0
# 3133    1.0
# 3130    1.0
#        ...
# 1314    9.0
# 404     9.0
# 3463    9.0
# 212     9.0
# 3331    9.0
# Name: Previous Owners, Length: 3669, dtype: float64

# %%
car_df[car_df['Previous Owners'] == 9]
# Out:
#                title  Price  Mileage(miles)  Registration_Year  \
# 212   VAUXHALL CORSA   1500           96270               2008
# 404     BMW 3 SERIES   2500          138910               2003
# 1314      MINI HATCH   1875           98710               2007
# 3331  PEUGEOT 207 SW    895          114312               2008
# 3463  PEUGEOT 207 SW   1450          115000               2009
#
#       Previous Owners Fuel type    Body type  Engine Gearbox  Doors  Seats  \
# 212               9.0    Petrol    Hatchback     1.4  Manual    5.0    5.0
# 404               9.0    Petrol  Convertible     2.5  Manual    2.0    4.0
# 1314              9.0    Petrol    Hatchback     1.6  Manual    3.0    4.0
# 3331              9.0    Petrol       Estate     1.4  Manual    5.0    5.0
# 3463              9.0    Petrol       Estate     1.4  Manual    5.0    5.0
#
#       Emission Class Service history     brand         country
# 212              4.0          Uknown  VAUXHALL  United Kingdom
# ...

# %%
car_df.groupby('brand')['Price'].agg(['mean', 'std'])
# Out:
#                        mean          std
# brand
# ABARTH         11216.333333  6039.482621
# ALFA            3197.388889  2495.694814
# AUDI            7719.527397  4866.621560
# BMW             8325.981343  6036.639654
# CHEVROLET       3331.642857  1306.453191
# CHRYSLER        2433.800000   796.043152
# CITROEN         4652.873684  3291.745835
# DACIA           7439.571429  3647.734338
# DAEWOO           995.000000          NaN
# DAIHATSU        1695.000000   282.842712
# DODGE           3250.000000          NaN
# DS             14293.833333  7117.793490
# FIAT            4115.359223  2352.965329
# FORD            4859.144254  3641.400692
# HONDA           3871.953704  2954.578030
# HYUNDAI         4997.118280  3881.244925
# INFINITI        8625.714286  1925.935419
# ISUZU           2250.000000          NaN
# JAGUAR          8680.766667  4615.343456
# JEEP            2949.444444  3012.049182
# KIA             7733.073171  4010.219035
# LAGONDA        14995.000000          NaN
# ...

# %%
pd.pivot_table(data=car_df,values='Price' ,index='brand', columns='Fuel type')
# Out:
# Fuel type            Diesel  Diesel Hybrid  Electric        Petrol  \
# brand
# ABARTH                  NaN            NaN       NaN  11216.333333
# ALFA            4214.666667            NaN       NaN   2688.750000
# AUDI            8731.301205            NaN       NaN   6386.555556
# BMW             7342.022222        23220.0       NaN   7058.486239
# CHEVROLET       5249.500000            NaN       NaN   3012.000000
# CHRYSLER                NaN            NaN       NaN   2433.800000
# CITROEN         4026.891892            NaN       NaN   5052.206897
# DACIA           6754.600000            NaN       NaN   7820.111111
# DAEWOO                  NaN            NaN       NaN    995.000000
# DAIHATSU                NaN            NaN       NaN   1695.000000
# DODGE                   NaN            NaN       NaN   3250.000000
# DS             14025.000000            NaN       NaN  10981.000000
# FIAT            5036.777778            NaN       NaN   4027.138298
# ...

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              3.0
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              3.0
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history     brand         country
# ...

# %%
sns.scatterplot( x= car_df['Previous Owners'], y = car_df['Price'])
# Out:
# <AxesSubplot:xlabel='Previous Owners', ylabel='Price'>

# %%
sns.scatterplot( x= car_df['Registration_Year'], y = car_df['Price'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_55/3840075308.py in <module>
# ----> 1 sns.scatterplot( x= car_df['Registration_Year'], y = car_df['Price'])
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
sns.scatterplot( x= car_df['Registration_Year'], y = np.log(car_df['Price']))
# Out:
# <AxesSubplot:xlabel='Registration_Year', ylabel='Price'>

# %%
car_df.head()
# Out:
#             title  Price  Mileage(miles)  Registration_Year  Previous Owners  \
# 0     SKODA FABIA   6900           70189               2016              3.0
# 1  VAUXHALL CORSA   1495           88585               2008              4.0
# 2     HYUNDAI I30    949          137000               2011              3.0
# 3      MINI HATCH   2395           96731               2010              5.0
# 4  VAUXHALL CORSA   1000           85000               2013              3.0
#
#   Fuel type  Body type  Engine Gearbox  Doors  Seats  Emission Class  \
# 0    Diesel  Hatchback     1.4  Manual    5.0    5.0             6.0
# 1    Petrol  Hatchback     1.2  Manual    3.0    5.0             4.0
# 2    Petrol  Hatchback     1.4  Manual    5.0    5.0             5.0
# 3    Petrol  Hatchback     1.4  Manual    3.0    4.0             4.0
# 4    Diesel  Hatchback     1.3  Manual    5.0    5.0             5.0
#
#   Service history     brand         country
# ...

# %%
# 특정 컬럼들이 몇 종류의 데이터로 이루어져 있는지 계산합니다.

car_df[['title','Fuel type','Body type','Gearbox','Emission Class','Service history','brand','country']].nunique()
# Out:
# title              448
# Fuel type            6
# Body type           10
# Gearbox              2
# Emission Class       6
# Service history      2
# brand               48
# country             12
# dtype: int64

# %%
car_df.drop('title', axis = 1, inplace = True)

# %%
car_df['brand'].value_counts()
# Out:
# VAUXHALL         549
# FORD             409
# VOLKSWAGEN       271
# BMW              268
# PEUGEOT          245
# TOYOTA           193
# NISSAN           178
# RENAULT          175
# MERCEDES-BENZ    168
# AUDI             146
# HONDA            108
# FIAT             103
# MINI              97
# CITROEN           95
# HYUNDAI           93
# KIA               82
# SKODA             63
# SEAT              59
# MAZDA             53
# SUZUKI            41
# VOLVO             39
# LAND              35
# MITSUBISHI        32
# JAGUAR            30
# ALFA              18
# CHEVROLET         14
# DACIA             14
# SUBARU            11
# LEXUS              9
# JEEP               9
# MG                 7
# SAAB               7
# INFINITI           7
# DS                 6
# CHRYSLER           5
# ROVER              5
# SMART              4
# MASERATI           3
# ABARTH             3
# PROTON             3
# PORSCHE            3
# DAIHATSU           2
# SSANGYONG          2
# ...

# %%
car_df.groupby('brand')['Price'].mean()
# Out:
# brand
# ABARTH           11216.333333
# ALFA              3197.388889
# AUDI              7719.527397
# BMW               8325.981343
# CHEVROLET         3331.642857
# CHRYSLER          2433.800000
# CITROEN           4652.873684
# DACIA             7439.571429
# DAEWOO             995.000000
# DAIHATSU          1695.000000
# DODGE             3250.000000
# DS               14293.833333
# FIAT              4115.359223
# FORD              4859.144254
# HONDA             3871.953704
# HYUNDAI           4997.118280
# INFINITI          8625.714286
# ISUZU             2250.000000
# JAGUAR            8680.766667
# JEEP              2949.444444
# KIA               7733.073171
# LAGONDA          14995.000000
# LAND             10741.428571
# LEXUS             4213.222222
# MARCOS           11495.000000
# MASERATI         13300.000000
# MAZDA             5489.528302
# MERCEDES-BENZ     7703.041667
# MG                5622.285714
# MINI              6480.175258
# MITSUBISHI        3061.718750
# ...

# %%
vc = pd.DataFrame(car_df['brand'].value_counts())
vc
# Out:
#                brand
# VAUXHALL         549
# FORD             409
# VOLKSWAGEN       271
# BMW              268
# PEUGEOT          245
# TOYOTA           193
# NISSAN           178
# RENAULT          175
# MERCEDES-BENZ    168
# AUDI             146
# HONDA            108
# FIAT             103
# MINI              97
# CITROEN           95
# HYUNDAI           93
# KIA               82
# SKODA             63
# SEAT              59
# MAZDA             53
# SUZUKI            41
# VOLVO             39
# LAND              35
# MITSUBISHI        32
# JAGUAR            30
# ALFA              18
# CHEVROLET         14
# DACIA             14
# SUBARU            11
# LEXUS              9
# JEEP               9
# MG                 7
# SAAB               7
# INFINITI           7
# DS                 6
# CHRYSLER           5
# ROVER              5
# SMART              4
# MASERATI           3
# ABARTH             3
# PROTON             3
# PORSCHE            3
# DAIHATSU           2
# ...

# %%
pm = pd.DataFrame(
car_df.groupby('brand')['Price'].mean())
pm
# Out:
#                       Price
# brand
# ABARTH         11216.333333
# ALFA            3197.388889
# AUDI            7719.527397
# BMW             8325.981343
# CHEVROLET       3331.642857
# CHRYSLER        2433.800000
# CITROEN         4652.873684
# DACIA           7439.571429
# DAEWOO           995.000000
# DAIHATSU        1695.000000
# DODGE           3250.000000
# DS             14293.833333
# FIAT            4115.359223
# FORD            4859.144254
# HONDA           3871.953704
# HYUNDAI         4997.118280
# INFINITI        8625.714286
# ISUZU           2250.000000
# JAGUAR          8680.766667
# JEEP            2949.444444
# KIA             7733.073171
# LAGONDA        14995.000000
# LAND           10741.428571
# LEXUS           4213.222222
# MARCOS         11495.000000
# MASERATI       13300.000000
# MAZDA           5489.528302
# MERCEDES-BENZ   7703.041667
# MG              5622.285714
# MINI            6480.175258
# MITSUBISHI      3061.718750
# NISSAN          6529.415730
# ...

# %%
pm.join(vc, on='brand',how='left')
# Out:
#                       Price  brand
# brand
# ABARTH         11216.333333      3
# ALFA            3197.388889     18
# AUDI            7719.527397    146
# BMW             8325.981343    268
# CHEVROLET       3331.642857     14
# CHRYSLER        2433.800000      5
# CITROEN         4652.873684     95
# DACIA           7439.571429     14
# DAEWOO           995.000000      1
# DAIHATSU        1695.000000      2
# DODGE           3250.000000      1
# DS             14293.833333      6
# FIAT            4115.359223    103
# FORD            4859.144254    409
# HONDA           3871.953704    108
# HYUNDAI         4997.118280     93
# INFINITI        8625.714286      7
# ISUZU           2250.000000      1
# JAGUAR          8680.766667     30
# JEEP            2949.444444      9
# KIA             7733.073171     82
# LAGONDA        14995.000000      1
# LAND           10741.428571     35
# LEXUS           4213.222222      9
# MARCOS         11495.000000      1
# ...

# %%
vc.columns
# Out:
# Index(['brand', 'count'], dtype='object')

# %%
pm.columns
# Out:
# Index(['brand', 'Price'], dtype='object')

# %%
print(vc['brand'].dtype)
print(pm['brand'].dtype)
# Out:
# object
# object

# %%
vc.head()
# Out:
#         brand  count
# 0    VAUXHALL    549
# 1        FORD    409
# 2  VOLKSWAGEN    271
# 3         BMW    268
# 4     PEUGEOT    245

# %%
pm.head()
# Out:
#        brand         Price
# 0     ABARTH  11216.333333
# 1       ALFA   3197.388889
# 2       AUDI   7719.527397
# 3        BMW   8325.981343
# 4  CHEVROLET   3331.642857

# %%
vc = pd.DataFrame(car_df['brand'].value_counts())
pm = pd.DataFrame(
car_df.groupby('brand')['Price'].mean())
pm.join(vc, on='brand',how='left')
# Out:
#                       Price  brand
# brand
# ABARTH         11216.333333      3
# ALFA            3197.388889     18
# AUDI            7719.527397    146
# BMW             8325.981343    268
# CHEVROLET       3331.642857     14
# CHRYSLER        2433.800000      5
# CITROEN         4652.873684     95
# DACIA           7439.571429     14
# DAEWOO           995.000000      1
# DAIHATSU        1695.000000      2
# DODGE           3250.000000      1
# DS             14293.833333      6
# FIAT            4115.359223    103
# FORD            4859.144254    409
# HONDA           3871.953704    108
# HYUNDAI         4997.118280     93
# INFINITI        8625.714286      7
# ISUZU           2250.000000      1
# JAGUAR          8680.766667     30
# JEEP            2949.444444      9
# KIA             7733.073171     82
# LAGONDA        14995.000000      1
# LAND           10741.428571     35
# LEXUS           4213.222222      9
# MARCOS         11495.000000      1
# ...

# %%
vc = pd.DataFrame(car_df['brand'].value_counts()).reset_index().rename({"index":"brand", "brand": "count"},axis=1)
vc
# Out:
#             brand  count
# 0        VAUXHALL    549
# 1            FORD    409
# 2      VOLKSWAGEN    271
# 3             BMW    268
# 4         PEUGEOT    245
# 5          TOYOTA    193
# 6          NISSAN    178
# 7         RENAULT    175
# 8   MERCEDES-BENZ    168
# 9            AUDI    146
# 10          HONDA    108
# 11           FIAT    103
# 12           MINI     97
# 13        CITROEN     95
# 14        HYUNDAI     93
# 15            KIA     82
# 16          SKODA     63
# 17           SEAT     59
# 18          MAZDA     53
# 19         SUZUKI     41
# 20          VOLVO     39
# 21           LAND     35
# 22     MITSUBISHI     32
# 23         JAGUAR     30
# 24           ALFA     18
# 25      CHEVROLET     14
# 26          DACIA     14
# 27         SUBARU     11
# 28          LEXUS      9
# 29           JEEP      9
# 30             MG      7
# 31           SAAB      7
# 32       INFINITI      7
# 33             DS      6
# 34       CHRYSLER      5
# 35          ROVER      5
# ...

# %%
pm = pd.DataFrame(
car_df.groupby('brand')['Price'].mean()).reset_index()
pm
# Out:
#             brand         Price
# 0          ABARTH  11216.333333
# 1            ALFA   3197.388889
# 2            AUDI   7719.527397
# 3             BMW   8325.981343
# 4       CHEVROLET   3331.642857
# 5        CHRYSLER   2433.800000
# 6         CITROEN   4652.873684
# 7           DACIA   7439.571429
# 8          DAEWOO    995.000000
# 9        DAIHATSU   1695.000000
# 10          DODGE   3250.000000
# 11             DS  14293.833333
# 12           FIAT   4115.359223
# 13           FORD   4859.144254
# 14          HONDA   3871.953704
# 15        HYUNDAI   4997.118280
# 16       INFINITI   8625.714286
# 17          ISUZU   2250.000000
# 18         JAGUAR   8680.766667
# 19           JEEP   2949.444444
# 20            KIA   7733.073171
# 21        LAGONDA  14995.000000
# 22           LAND  10741.428571
# 23          LEXUS   4213.222222
# 24         MARCOS  11495.000000
# 25       MASERATI  13300.000000
# 26          MAZDA   5489.528302
# 27  MERCEDES-BENZ   7703.041667
# ...

# %%
pm.join(vc, on='brand',how='left') #??기준 DataFrame은 컬럼, 조인 대상은 인덱스  인덱스-컬럼 조인 (제한적)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_55/1438468897.py in <module>
# ----> 1 pm.join(vc, on='brand',how='left')
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9098         5  K5  A5  NaN
#    9099         """
# -> 9100         return self._join_compat(
#    9101             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9102         )
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9129                     sort=sort,
#    9130                 )
# -> 9131             return merge(
#    9132                 self,
#    9133                 other,
#
# ...

# %%
car_df = pd.get_dummies(car_df, drop_first = True)

# %%
from sklearn.preprocessing import RobustScaler

# %%
rs =RobustScaler()

# %%
car_df = rs.fit_transform(car_df)
## car_df = pd.DataFrame(rs.fit_transfrom(car_df) , columns= car_df.columns)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(5)

# %%
pca.fit(car_df)
# Out:
# PCA(n_components=5)

# %%
round((pca.explained_variance_ratio_).sum(), 2)
# Out:
# 0.64

# %%
for i in range(2, 11):
    pca = PCA(i)
    pca.fit(car_df)
    print(i, round(pca.explained_variance_ratio_.sum(), 2))
# Out:
# 2 0.41
# 3 0.52
# 4 0.59
# 5 0.64
# 6 0.68
# 7 0.71
# 8 0.74
# 9 0.77
# 10 0.79

# %%
pca = PCA(7)
pca.fit(car_df)
# Out:
# PCA(n_components=7)

# %%
pca_result = pca.transform(car_df)
pd.DataFrame(pca_result)
# Out:
#              0         1         2         3         4         5         6
# 0    -0.514980 -0.422637 -0.415003  0.646676  0.287282  0.032610 -0.017734
# 1     1.312384 -1.217170  0.349554 -0.268356 -0.159763  0.998415  0.070210
# 2     0.812080 -0.223882  1.006030  0.654407  0.663232  0.051150  0.084723
# 3     1.961983 -1.312642 -0.517619 -0.709751  0.546531  0.644088  0.133232
# 4     0.267575 -0.653314  0.514638  0.555964 -0.125742  1.161923  0.179275
# ...        ...       ...       ...       ...       ...       ...       ...
# 3664  1.427772 -0.807223  0.187850  0.093612 -0.565527 -0.429525 -0.000996
# 3665  0.435272  1.081559 -0.283845 -0.141185  0.549215 -0.033512 -0.091071
# 3666  0.757281  1.455642 -0.085260  0.230944  0.864446  0.084921  0.061965
# 3667  1.658730  1.682128  1.001384  0.811344  0.409603 -0.056047  0.769015
# 3668  2.919977 -2.386255 -1.901952  0.806527  0.060973  1.044695  0.021803
#
# [3669 rows x 7 columns]

# %%
pd.DataFrame(bonus_df.groupby('country')['brand'].unique())['brand'].map(len)

##pd.DataFrame(bonus_df.groupby('country')['brand'].nunique())
# Out:
# country
# Czech Republic     1
# France             4
# Germany            6
# Italy              4
# Japan             11
# Malaysia           1
# Romania            1
# South Korea        4
# Spain              1
# Sweden             2
# United Kingdom     8
# United States      5
# Name: brand, dtype: int64

# %%
bonus_df.corr()
# Out:
#                       Price  Mileage(miles)  Registration_Year  \
# Price              1.000000       -0.500358           0.722971
# Mileage(miles)    -0.500358        1.000000          -0.410781
# Registration_Year  0.722971       -0.410781           1.000000
# Previous Owners   -0.479424        0.316160          -0.501045
# Doors              0.113335       -0.037024           0.219365
# Seats             -0.027393        0.095271           0.037166
#
#                    Previous Owners     Doors     Seats
# Price                    -0.479424  0.113335 -0.027393
# Mileage(miles)            0.316160 -0.037024  0.095271
# Registration_Year        -0.501045  0.219365  0.037166
# Previous Owners           1.000000 -0.153262 -0.029338
# Doors                    -0.153262  1.000000  0.497160
# Seats                    -0.029338  0.497160  1.000000
